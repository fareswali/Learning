# %% [markdown]
# <a href="https://colab.research.google.com/github/fareswali/Learning/blob/main/01-python/day-01-python-practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1 Python Practice
# Goal: Practise basic Python concepts

name = "Fares"
target_role = "AI Product Manager"
skills = ["Python", "SQL", "AI", "Product Management"]

print("Hello, my name is " + name)
print("My target role is " + target_role)
print("Skills I am learning:")

for skill in skills:
    print("- " + skill)


def introduce_person(name, role):
    return "My name is " + name + " and I am learning to become an " + role


message = introduce_person(name, target_role)
print(message)
# Out:
# Hello, my name is Fares
# My target role is AI Product Manager
# Skills I am learning:
# - Python
# - SQL
# - AI
# - Product Management
# My name is Fares and I am learning to become an AI Product Manager
